# %% [markdown]
# <a href="https://colab.research.google.com/github/lesya7maltseva/Pandas-Statistics-/blob/main/Pandas_loc%2C_groupby%2C_method_chain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Загрузите этот файл в датафрейм Pandas (с именем df). Однако, будьте осторожны - перед отправкой кода на проверку посмотрите на свой результат и убедитесь, что вы все загрузили корректно.
#
#
# Отфильтруйте только тех пользователей, у которых id >= 94. Пользователи с меньшим id - фейковые, они сбивают статистику.
# 2. Также уберите пользователей с одним из этих ников: 'fnoxonsnbkbxsnb', 'Jonns21241412', 'fbxbnsn'. Это также фейковые юзеры
#
# Создайте столбец cohort, который будет содержать год и месяц регистрации в формате YYYY-MM.
#
# Создайте переменную res, которая будет содержать долю каждой когорты в общем количестве зарегистрированных пользователей. В сумме все доли должны давать 100.

# %%
df = pd.read_csv('itresume-users-pandas.csv', sep = ';', skiprows=1)
df
# Out:
#       id       username          date_joined
# 0    416  nsosabisfsobm  2022-01-02 12:22:43
# 1     43    NbabnnbTona  2021-07-01 09:11:42
# 2     50           jbdn  2021-08-04 09:01:56
# 3    249       Kbaoxsnb  2021-11-27 07:03:35
# 4     77   bxakbasmo$$$  2021-11-09 14:31:46
# ..   ...            ...                  ...
# 95   946     Mbbn$xb$eo  2022-01-29 18:04:23
# 96   947            NaN  2022-01-29 18:31:26
# 97  1050     nsosabndsi  2022-02-01 21:02:59
# 98  1076    SbsdSaobdox  2022-02-02 19:31:21
# 99  1090           Addb  2022-02-03 13:14:15
#
# [100 rows x 3 columns]

# %%
df = df.loc[(df['id']>=94) & (~df['username'].isin(['fnoxonsnbkbxsnb', 'Jonns21241412', 'fbxbnsn'])), :]
df
# Out:
#       id       username          date_joined
# 0    416  nsosabisfsobm  2022-01-02 12:22:43
# 3    249       Kbaoxsnb  2021-11-27 07:03:35
# 7   2633           Eabx  2022-04-06 08:52:40
# 12   219         Sbjssb  2021-11-24 17:11:49
# 13   220      Nsobdbs78  2021-11-24 17:25:31
# ..   ...            ...                  ...
# 95   946     Mbbn$xb$eo  2022-01-29 18:04:23
# 96   947            NaN  2022-01-29 18:31:26
# 97  1050     nsosabndsi  2022-02-01 21:02:59
# 98  1076    SbsdSaobdox  2022-02-02 19:31:21
# 99  1090           Addb  2022-02-03 13:14:15
#
# [91 rows x 3 columns]

# %%
df['cohort'] = pd.to_datetime(df.loc[:,'date_joined']).dt.strftime('%Y-%m')
# Out:
# <ipython-input-15-6eca3d965468>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cohort'] = pd.to_datetime(df.loc[:,'date_joined']).dt.strftime('%Y-%m')

# %%
df_cohorts = df.groupby('cohort')['id'].agg('sum').reset_index()
df_cohorts
# Out:
#     cohort     id
# 0  2021-11   8508
# 1  2021-12  10037
# 2  2022-01  14372
# 3  2022-02   3216
# 4  2022-04   2633

# %%
df.groupby('cohort')['id'].agg('sum').transform(lambda x: x*100/sum(x)).reset_index()
# Out:
#     cohort         id
# 0  2021-11  21.947067
# 1  2021-12  25.891245
# 2  2022-01  37.073724
# 3  2022-02   8.295929
# 4  2022-04   6.792034

# %%
res = df.cohort.value_counts(normalize=True) * 100
res
# Out:
# cohort
# 2021-11    37.362637
# 2021-12    31.868132
# 2022-01    26.373626
# 2022-02     3.296703
# 2022-04     1.098901
# Name: proportion, dtype: float64

# %% [markdown]
# Загрузите этот файл в датафрейм Pandas и назовите его coderun.
#
#
# Создайте столбец cohort, который будет содержать год и месяц регистрации в формате YYYY-MM.
#
# Создайте столбец language, который проводит соответствие между языком и language_id по правилу:
#
# А теперь давайте посчитаем - в скольких задачах в среднем один пользователь отправлял на выполнение код в каждой когорте по каждому языку.
#
# Примечание: Задача не может быть одновременно и на SQL, и на Python.
#
# Результатом должна стать «широкая» таблица, где:
#
#
# строки - когорты, но только после января 2022 года (включительно)
#
# столбцы - языки
#
# значения - число задач, по которым пользователи в данной когорте отправляют код на выполнение по данному языку в среднем

# %%
coderun = pd.read_csv('itresume-coderun.csv')

# %%
dct_language = {3:'Python', 2:'SQL' }

# %%
coderun['language'] = coderun.language_id.map(dct_language)

# %%
coderun['cohort'] = pd.to_datetime(coderun['created_at']).dt.strftime('%Y-%m')
coderun
# Out:
#           id               created_at  problem_id  user_id  language_id  \
# 19121  19122  2022-02-01 04:28:28.547         136      566            2
# 19122  19123  2022-02-01 04:29:21.071         136      566            2
# 19123  19124  2022-02-01 04:31:19.603         136      566            2
# 19124  19125  2022-02-01 04:33:54.636         136      566            2
# 19125  19126  2022-02-01 04:38:14.099         137      566            2
# ...      ...                      ...         ...      ...          ...
# 55717  55718  2022-05-17 09:00:51.743         101      171            2
# 55718  55719  2022-05-17 09:01:04.210         101      171            2
# 55719  55720  2022-05-17 09:02:06.203         101      171            2
# 55720  55721  2022-05-17 09:03:45.265         102      171            2
# 55721  55722  2022-05-17 09:03:57.645         102      171            2
#
#       language   cohort
# 19121      SQL  2022-02
# 19122      SQL  2022-02
# 19123      SQL  2022-02
# ...

# %%
coderun = coderun.loc[coderun['cohort']>='2022-01']
df = coderun.groupby(['cohort','language','user_id']).agg({'problem_id':'nunique'}).reset_index()
df = df.groupby(['cohort','language']).agg({'problem_id': np.mean}).reset_index()
df.pivot_table(values= 'problem_id', index='cohort', columns='language')
# Out:
# <ipython-input-113-c60ee15b766e>:3: FutureWarning: The provided callable <function mean at 0x7df9ccb2eb60> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df = df.groupby(['cohort','language']).agg({'problem_id': np.mean}).reset_index()
# language    Python        SQL
# cohort
# 2022-02   2.684524   4.742358
# 2022-03   2.330000   5.277778
# 2022-04   6.659794   8.073684
# 2022-05   5.833333  10.451613

# %% [markdown]
# через метод method chain (сначала кажется сложновато, но нереально круто выглядит и не надо городит огород как в примере сверху)

# %%
df = (
    coderun.loc[coderun['cohort']>='2022-01']
    .groupby(['cohort','language','user_id'])
    .agg({'problem_id':'nunique'})
    .groupby(['cohort','language'])
    .agg({'problem_id': np.mean})
    .pivot_table(values= 'problem_id', index='cohort', columns='language')
    )

df
# Out:
# <ipython-input-115-d8332d48e78c>:6: FutureWarning: The provided callable <function mean at 0x7df9ccb2eb60> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   .agg({'problem_id': np.mean})
# language    Python        SQL
# cohort
# 2022-02   2.684524   4.742358
# 2022-03   2.330000   5.277778
# 2022-04   6.659794   8.073684
# 2022-05   5.833333  10.451613

# %% [markdown]
# Загрузите файл в датафрейм Pandas и назовите его coderun. Далее создайте 2 переменные:
#
# problem_id - список задач, которые нужно исключить. Значения: 1, 2, 3, 13, 15, 26.
# language_id - номер языка, который нужно оставить. Значение: 2.
# С помощью query отфильтруйте coderun по этим двум переменным. Результат сохраните в датафрейм df

# %%
coderun = pd.read_csv('itresume-coderun.csv')
problem_id = [1, 2, 3, 13, 15, 26]
language_id = 2

# %%
coderun.query('problem_id not in @problem_id and language_id == 2')
# Out:
#           id               created_at  problem_id  user_id  language_id
# 4          5  2021-03-30 11:29:12.000          21       18            3
# 5          6  2021-04-19 08:07:46.000          23        3            3
# 7          8  2021-03-29 03:46:24.000           6        9            3
# 8          9  2021-04-06 12:14:59.000          24        1            3
# 9         10  2021-04-15 11:07:15.000          20       17            3
# ...      ...                      ...         ...      ...          ...
# 55678  55679  2022-05-17 01:09:18.354          49     2605            3
# 55679  55680  2022-05-17 01:09:53.580          49     2605            3
# 55680  55681  2022-05-17 01:13:18.370          49     2605            3
# 55681  55682  2022-05-17 01:14:08.825          49     2605            3
# 55682  55683  2022-05-17 01:15:40.000          49     2605            3
#
# [10839 rows x 5 columns]

# %% [markdown]
# Загрузите файлы в датафреймы Pandas и назовите их coderun и users. Далее создайте новый датафрейм df, который получается в результате:
#
# Объединения двух датафреймов по полям с пользователем
# Если для каких-то кодранов не найдена пара в таблице users, такие записи нужно все равно оставить в результирующей таблице
# Если есть совпадающие названия столбцов, то у них в результате должны быть суффиксы _run и _user
# Далее выполните действия:
#
# Создайте новый датафрейм df2, который будет хранить информацию о том, сколько дней прошло между последним выполнением кода конкретного юзера и днем его регистрации. Столбец с разницей должен называться diff.
# Округлите diff до ближайшего меньшего числа, кратного 50. Результат должен остаться целым числом.
# Создайте датафрейм df3, в который запишите количество юзеров, сгруппированных по разнице дней.
# Результат отсортируйте по убыванию количества user_id

# %%
coderun = pd.read_csv('itresume-coderun.csv')
users = pd.read_csv('itresume-users-pandas.csv', sep = ';', skiprows=1)

# %%
df = coderun.merge(users, left_on= 'user_id', right_on= 'id', how = 'left', suffixes=['_run', '_user'])
df
# Out:
#        id_run               created_at  problem_id  user_id  language_id  \
# 0           1  2021-04-07 06:06:20.000          13       10            3
# 1           2  2021-03-31 07:10:06.000          15       13            3
# 2           3  2021-04-04 14:55:26.000           1        6            3
# 3           4  2021-03-29 21:24:51.000          26        4            3
# 4           5  2021-03-30 11:29:12.000          21       18            3
# ...       ...                      ...         ...      ...          ...
# 55717   55718  2022-05-17 09:00:51.743         101      171            2
# 55718   55719  2022-05-17 09:01:04.210         101      171            2
# 55719   55720  2022-05-17 09:02:06.203         101      171            2
# 55720   55721  2022-05-17 09:03:45.265         102      171            2
# 55721   55722  2022-05-17 09:03:57.645         102      171            2
#
#        id_user username date_joined
# 0          NaN      NaN         NaN
# ...

# %%
df2 = (
    df.groupby('user_id')
    .apply(lambda x: pd.Series({'diff': max(pd.to_datetime(x['created_at']) - pd.to_datetime(x['date_joined'])).days}))
    .reset_index()
    )

df2['diff'] = (df2['diff']/50).apply(np.floor)*50
# Out:
# <ipython-input-27-685a4dc41114>:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: pd.Series({'diff': max(pd.to_datetime(x['created_at']) - min(pd.to_datetime(x['date_joined']))).days}))

# %%
df3 = (
    df2.groupby('diff', dropna= False)
    .agg({'user_id':'count'})
    .reset_index()
    .sort_values('user_id', ascending= False)
    )
df3
# Out:
#     diff  user_id
# 5    NaN      795
# 0    0.0       41
# 2  100.0       16
# 1   50.0       11
# 3  150.0        3
# 4  250.0        2

# %%
df_n = coderun.merge(users, how='left', left_on='user_id', right_on='id', suffixes=['_run', '_user'])

df2_1 = (
    df_n
    .groupby('user_id')
    .apply(lambda x: pd.Series(
            data=(max(pd.to_datetime(x['created_at'])) - min(pd.to_datetime(x['date_joined']))).days,
            index=['diff']
        )
    )
    .reset_index()
)

df2_1['diff'] = (
    (df2['diff']/50)
    .apply(np.floor)*50
).astype("Int64")

df3_1 = (
    df2
    .groupby('diff', dropna=False)
    .agg({'user_id': 'count'})
    .reset_index()
    .sort_values(by='user_id', ascending=False)
)
# Out:
# <ipython-input-29-9fd6a05c249d>:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: pd.Series(

# %%
df3_1
# Out:
#     diff  user_id
# 5    NaN      795
# 0    0.0       41
# 2  100.0       16
# 1   50.0       11
# 3  150.0        3
# 4  250.0        2
